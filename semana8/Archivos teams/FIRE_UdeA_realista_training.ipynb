# %% [markdown]
# # FIRE-UdeA — Dataset Realista y Entrenamiento (Reproducible)

# %% [markdown]
# Carga `dataset_sintetico_FIRE_UdeA_realista.csv`, entrena el modelo y produce métricas por split.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
print(pd.read_csv("dataset_sintetico_FIRE_UdeA_realista.csv").head())
